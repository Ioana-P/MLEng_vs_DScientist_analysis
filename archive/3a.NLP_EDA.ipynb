# %% [markdown]
# <a id=contents></a>
#
# # Exploratory Data Analysis of Natural Language Processing Jobs
# ## Our clean data at a glance
#
#
# [1. Visualizing and exploring the Job Title field](#insp)
#
# [2. EDA](#eda)
#
# [3. Summary of findings](#conc)

# %%
import pandas as pd
import numpy as np

from sklearn.cluster import KMeans
import scipy.cluster.hierarchy as shc

import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline
sns.set_style("darkgrid")

from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
import nltk
from sklearn.linear_model import LogisticRegression
from nltk.probability import FreqDist
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from sklearn.metrics import confusion_matrix, multilabel_confusion_matrix
from sklearn.naive_bayes import MultinomialNB
from sklearn import metrics
from sklearn.model_selection import train_test_split, GridSearchCV
from matplotlib import cm
import numpy as np
from sklearn.ensemble import RandomForestClassifier,GradientBoostingClassifier
from sklearn.metrics import accuracy_score, roc_auc_score, roc_curve
from sklearn.metrics import f1_score
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import silhouette_score
from sklearn.cluster import KMeans
from sklearn.decomposition import TruncatedSVD
from sklearn.tree import DecisionTreeClassifier
import string
# !pip install wordcloud
import wordcloud
from nltk.corpus import stopwords
from nltk.tokenize import RegexpTokenizer
import re
tokenizer = RegexpTokenizer(r'\b\w{3,}\b')
stop_words = list(set(stopwords.words("english")))
stop_words += list(string.punctuation)

import warnings
warnings.filterwarnings('ignore')


import functions as fn

# %load_ext autoreload
# %autoreload 2

# %%
# updating our stop word list to include NLP title terms like 'language', 'natural'
nlp_stop_word_lst = fn.gen_stopwords(['data', 'experience', 'learning', 'science', 'machine', 
                                      'work', 'company', 'role', 'the', 'skills', ' data',
                                      '000', 'data', 'the', 'join', 'you''engineer', 
                                      'scientist', 'software', 
                                      'science', 'machine', 'data', 'analyst', 
                                      'experience', 'work', 'working', 
                                      'language', 'natural', 'nlp', 
                                     'processing'])

# %% [markdown]
# <a id=insp ><a/>
#
# ## 1. ETL and defining what are NLP jobs
#
# [LINK to table of contents](#contents)

# %% [markdown]
# After extracting our data, it it important that we define what we mean by Natural Language Processing (NLP) jobs. A significant portion of the other batches we retrieved, where our search terms were 'data scientist' and 'machine learning engineer' will have contained NLP as part of the description and maybe even the title. It's not uncommon to expect a lot of ML and DS jobs to include some features of NLP work, alongside other parts of the job. However, since we're looking here for a very specific type of job, where the role is *centred* on NLP. How do we go about selecting such a subset of jobs accurately?
#
# My choice is to select the subset of jobs that contain some variation of 'NLP'/ 'Natural Language' in them. My reasoning is that if a job post is truly centred on that function within a company then it would be mentioned in the title. In the case where jobs simply say something akin to "Data Scientist - NLP preferable" I would still include this since it's likely that the skills mentioned after will be highly relevant to our search.

# %%
df = pd.read_csv('clean_nlp_data.csv')
df.drop(columns=['Unnamed: 0'], inplace=True)
df.head()
# Out:
#                            company  \
# 0         Kubrick Group-London SE1
# 1              Securium LTD-Surrey
# 2        Digital insight-London N1
# 3                  Facebook-London
# 4  Evi Technologies Limited-London
#
#                                            job_title  \
# 0          Machine Learning Engineer Graduate Scheme
# 1                      Software Engineer / Developer
# 2                  Natural Language Processing (NLP)
# 3  Research Scientist, Natural Language Processin...
# 4  Applied Scientist - Information Retrieval and ...
#
#                                            job_descr  \
# 0  Would you love explore career Data Science Eng...
# 1  Securium advanced cyber focused developing sec...
# 2  specialise and differentiate our ability extra...
# 3  Facebook mission give people the power and bri...
# 4  Machine Learning related disciplineStrong publ...
#
#                job_search_term job_location  \
# 0  natural language processing       London
# 1  natural language processing       London
# 2  natural language processing       London
# 3  natural language processing       London
# 4  natural language processing       London
#
#                                              job_url  \
# 0  https://www.indeed.co.uk/pagead/clk?mo=r&ad=-6...
# 1  https://www.indeed.co.uk/pagead/clk?mo=r&ad=-6...
# 2  https://www.indeed.co.uk/rc/clk?jk=bfd3b0a1b6f...
# 3  https://www.indeed.co.uk/rc/clk?jk=2e174837e3a...
# 4  https://www.indeed.co.uk/rc/clk?jk=edc11c5d777...
#
#    salary_from_page_source_as_stated  salary_from_page_source_conv_hourly  \
# 0                            32000.0                                  NaN
# 1                                NaN                                  NaN
# 2                                NaN                                  NaN
# 3                                NaN                                  NaN
# 4                                NaN                                  NaN
#
#    salary_from_page_source_time_period  Num_reviews
# 0                                  NaN          NaN
# 1                                  NaN          NaN
# 2                                  NaN          NaN
# 3                                  NaN        579.0
# 4                                  NaN      63542.0

# %%
def does_it_include_nlp(job_title):
    if re.findall(r'langua', job_title.lower()):
        return 1
    elif re.findall(r'nlp', job_title.lower()):
        return 1
    elif re.findall(r'linguis', job_title.lower()):
        return 1
    elif re.findall(r'text', job_title.lower()):
        return 1
    else:
        return 0

test_str = ' Research Scientist, Natural Language'

does_it_include_nlp(test_str)
# Out:
# 1

# %%
df['title_inc_nlp'] = df.job_title.apply(does_it_include_nlp)
df.head()
# Out:
#                            company  \
# 0         Kubrick Group-London SE1
# 1              Securium LTD-Surrey
# 2        Digital insight-London N1
# 3                  Facebook-London
# 4  Evi Technologies Limited-London
#
#                                            job_title  \
# 0          Machine Learning Engineer Graduate Scheme
# 1                      Software Engineer / Developer
# 2                  Natural Language Processing (NLP)
# 3  Research Scientist, Natural Language Processin...
# 4  Applied Scientist - Information Retrieval and ...
#
#                                            job_descr  \
# 0  Would you love explore career Data Science Eng...
# 1  Securium advanced cyber focused developing sec...
# 2  specialise and differentiate our ability extra...
# 3  Facebook mission give people the power and bri...
# 4  Machine Learning related disciplineStrong publ...
#
#                job_search_term job_location  \
# 0  natural language processing       London
# 1  natural language processing       London
# 2  natural language processing       London
# 3  natural language processing       London
# 4  natural language processing       London
#
#                                              job_url  \
# 0  https://www.indeed.co.uk/pagead/clk?mo=r&ad=-6...
# 1  https://www.indeed.co.uk/pagead/clk?mo=r&ad=-6...
# 2  https://www.indeed.co.uk/rc/clk?jk=bfd3b0a1b6f...
# 3  https://www.indeed.co.uk/rc/clk?jk=2e174837e3a...
# 4  https://www.indeed.co.uk/rc/clk?jk=edc11c5d777...
#
#    salary_from_page_source_as_stated  salary_from_page_source_conv_hourly  \
# 0                            32000.0                                  NaN
# 1                                NaN                                  NaN
# 2                                NaN                                  NaN
# 3                                NaN                                  NaN
# 4                                NaN                                  NaN
#
#    salary_from_page_source_time_period  Num_reviews  title_inc_nlp
# 0                                  NaN          NaN              0
# 1                                  NaN          NaN              0
# 2                                  NaN          NaN              1
# 3                                  NaN        579.0              1
# 4                                  NaN      63542.0              1

# %%
df[['job_title', 'title_inc_nlp']].head(20)
# Out:
#                                             job_title  title_inc_nlp
# 0           Machine Learning Engineer Graduate Scheme              0
# 1                       Software Engineer / Developer              0
# 2                   Natural Language Processing (NLP)              1
# 3   Research Scientist, Natural Language Processin...              1
# 4   Applied Scientist - Information Retrieval and ...              1
# 5   Quantitative Researcher in Natural Language Pr...              1
# 6      Research Fellow in Natural Language Processing              1
# 7                  Junior Machine Learning Consultant              0
# 8            Natural Language Processing Engineer PhD              1
# 9               Natural Language Processing Engineers              1
# 10                      Research Intern (AI) - London              0
# 11                 AI Research Scientist (All Levels)              0
# 12                             Sr. Research Scientist              0
# 13  Junior Research Scientist, Support Operations ...              0
# 14                  Customer Success Insights Analyst              0
# 15                            Graduate Data Scientist              0
# 16                               Partnerships Manager              0
# 17                                  Software Engineer              0
# 18                                        QA Engineer              0
# 19        Research Engineer - Artificial Intelligence              0

# %%
nlp_df = df.loc[df.title_inc_nlp == 1]
nlp_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 17 entries, 2 to 121
# Data columns (total 11 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   company                              17 non-null     object
#  1   job_title                            17 non-null     object
#  2   job_descr                            17 non-null     object
#  3   job_search_term                      17 non-null     object
#  4   job_location                         17 non-null     object
#  5   job_url                              17 non-null     object
#  6   salary_from_page_source_as_stated    5 non-null      float64
#  7   salary_from_page_source_conv_hourly  0 non-null      float64
#  8   salary_from_page_source_time_period  0 non-null      float64
#  9   Num_reviews                          10 non-null     float64
#  10  title_inc_nlp                        17 non-null     int64
# dtypes: float64(4), int64(1), object(6)
# memory usage: 1.6+ KB

# %% [markdown]
# And right there we can see that we have a significantly smaller group of job posts. Let's analyse the 17 we have.
#
# <a id='eda'></a>
#
# ## 2. EDA
#
# [LINK to table of contents](#contents)

# %%
fn.plot_freqdist_from_series(nlp_df.job_descr, tokenizer, nlp_stop_word_lst);

# %% [markdown]
# * 'research' is mentioned heavily (~60 times across 17 jobs) - this could be an indication that NLP specific jobs often have a focus on bringing new ideas into the hiring company and scouting new solutions, OR that candidates should have experience of research in NLP. Let's look at bigrams and trigrams

# %%
fn.plot_freqdist_from_series(nlp_df.job_descr, tokenizer, nlp_stop_word_lst, ngram_number=2) ;

# %% [markdown]
# * 'information extraction' is mentioned 9 times, and if we consider 'extraction entity' to be a similar concept, then the total is 14 occurrences.

# %%
fn.plot_freqdist_from_series(nlp_df.job_descr, tokenizer, nlp_stop_word_lst, ngram_number=3);

# %% [markdown]
# * As was hinted in the bigram plot, the action/role of 'consultant' seems to feature fairly frequently in NLP jobs, occupying the first 3 trigrams in our last plot
# * Entity extraction is featured significantly with 4 separate trigrams featuring it, with an accumulated frequency of 11 (however the frequency is still quite low for the individual trigrams).

# %%
fn.gen_cloud(nlp_df.job_descr, 20, stop_word_lst, background_color='white', cloud_title='NLP Jobs description word cloud')

# %%
fn.gen_cloud(nlp_df.job_descr, 20, nlp_stop_word_lst,
             'white', cloud_title='NLP Jobs description word cloud')

# %% [markdown]
# ### So far, the most promising leads for further exploration are:
# - why and how do NLP jobs mention 'research' so heavily and how to capitalise on this?
# - how do theses frequencies compare with 123-wide pool of jobs that mention 'NLP' inside their description but not in their title?

# %%
for i in range(len(nlp_df)):
    print('Job descr nr #', i+1)
    print(nlp_df.job_descr.iloc[i])
    print('\n\n\n')
# Out:
# Job descr nr # 1
# specialise and differentiate our ability extract information and from unstructured text work with blend open source framework and build proprietary algorithm alongside and top these Our work relies the latest innovation the field reading researching and prototyping you are interested industrial scale applied NLP then would love talk you This developer role and you would have some prior experience developing system round Information extraction entity relationship entity resolution entity matching text summarisation and near duplicate detection
#
#
#
#
# Job descr nr # 2
# Facebook mission give people the power and bring the world closer together Through our family apps and service building different kind billion people around the world give them way share what matter most them and help bring people closer together Whether creating new product helping small business expand reach people Facebook are builder heart Our global team iterating solving problem and working together empower people around the world meaningful way Together can help people build just getting Billions people use our service their preferred language but many these language lack traditional NLP resource and our system need robust the informal tone slang and typo often found Our research span multiple area across NLP and machine learning including deep learning neural network machine translation natural language understanding and generation low resource NLP question answering dialogue and cross lingual and cross domain transfer learning are seeking world class natural language processing expert join our team developing next generation product and and publishing research and engineering scale applying language technology wide range medium understanding challenge Facebook Conduct research advance the state the art neural network and NLP Utilize that research develop and deploy scalable neural network model into production impact billion people using Facebook Collaborate with team member from other research and applied research team working variety deep learning and NLP problem Currently the process obtaining PhD degree postdoctoral assignment Natural Language Processing related field Experience with developing modern NLP system Proven track achieving result demonstrated grant fellowship patent well publication workshop such ACL EMNLP NAACL AAAI ICML NeurIPS similar Must obtain work authorization employment the time hire and maintain ongoing work authorization during employment
#
#
#
#
# Job descr nr # 3
# Machine Learning related disciplineStrong publication top such NeurIPS ICML AISTATS ICLR KDD CCS PETS etc Familiar with programming language language such Python Java etc Very good written and skill You Alexa looking for new impactful role where tackle the next big research challenge what you suggest Alexa The Alexa Shopping team looking for applied research leader scientist help the best personal assistant you want hear more You Yes please Alexa Applied Scientist the Alexa Shopping team you will investigating and developing machine learning and natural language processing technology help Alexa turn into the best and most trustworthy personal assistant The team you will specifically working with expertise deep learning user modelling Gaussian process probabilistic modelling information retrieval crowdsourcing and other related field employ all these technology improve the experience Alexa customer focusing the shopping domain Your work within this team research machine learning and natural language processing system and software development exploration new technology well publication and presentation top year industrial academic experience machine learning natural language processing and application statistical methodsExperience serving senior role top Take look http www amazon science learn more about research highlight and publication from the Amazon science team Amazon equal opportunity employer believe passionately that employing diverse workforce central our success make recruiting decision based your experience and skill value your passion invent simplify and build Protecting your privacy and the security your data longstanding top priority for Amazon our Privacy Notice know more about how use and transfer the personal data our candidate NicheTech NicheTechUK IRresearch
#
#
#
#
# Job descr nr # 4
# Imagine introducing the next generation technology platform real time Research leading quantitative research and using the latest scientific technique produce world beating research and build advanced technology analyse the world data are developing the next generation infrastructure that can effortlessly scale and flex This capability allows adapt the demanding the business process and analyse large and varied data set Imagine beating the efficient market hypothesis with the full big data toolset Research leading quantitative research and using the latest scientific technique produce world beating research and build advanced technology analyse the world data use the latest scientific technique and advanced data analysis method the Our researcher are free explore idea finding pattern large noisy and real world data set the movement global financial market The Role You will join team NLP expert and quantitative researcher working very large applying the latest technique for entity sentiment analysis and topic extraction with the goal identifying feature real time text that can used the future behaviour financial market Who are looking for ideal candidate you will expert Natural Language Processing through academic industry experience both You will have experience applying machine learning and deep learning method range NLP related task such Named Entity Entity Linking Sentiment Analysis Graphs MultiLingual Text and Topic Extraction You will have experience working with existing NLP and deep learning framework such word spaCy CoreNLP NLTK PyTorch TensorFlow and Keras You will familiar with the many recent exciting advance NLP such pre trained language word attention and novel neural network architecture You will have interest applying real world financial data and implementing theoretical insight You will have working towards gaining Masters PhD degree NLP Computational Linguistics related quantitative subject such machine science mathematics statistic physic engineering Publications leading such ACL and EMNLP and such NeurIPS and ICML are highly desirable Previous financial experience not although interest finance and the motivation rapidly learn more prerequisite for working here Why should you plus annual discretionary bonus Informal and excellent work life balance Comprehensive healthcare and life assurance day holiday Pension Cycle work scheme Subsidised gym membership event Central London office close station and tube line
#
#
#
#
# Job descr nr # 5
# Are you excellent data scientist with clear research vision looking secure personal fellowship and establish your own research group The Data Science Institute DSI Imperial College wish nurture the next generation outstanding researcher and invite application for attractive and flexible fellowship scheme for those wishing develop independent research career You will carry out plan and lead high quality programme research Natural Language Processing and application undertake project management and supervise multi disciplinary team addition the Fellow will expected submit publication refereed journal and attract external research funding Duties and responsibility and original research Natural Language Processing and application obtain research grant from national and international funding body and obtain funding from industry where appropriate publish research paper peer reviewed journal attend and present research supervise postdoctoral researcher postgraduate student and undergraduate research project the DSI Essential requirement are looking for researcher any stage their career who have very good academic track including first upper degree and PhD science closely related discipline equivalent research industrial experience Experience the supervision research undergraduate postgraduate student postdoctoral staff Experience statistic data mining machine learning and natural language processing Experience directing the work small research team and motivate others produce high standard work Good modern programming language Java Python and management technology Docker Openstack Further information Contract Fixed Term for month Please apply via our website http www imperial job and search using vacancy reference number ENG01319 For query regarding the application Fay Miller For technical issue when applying online Documents Job Description ENG01319 pdf
#
#
#
#
# Job descr nr # 6
# The Company have excellent root within research surrounding new information retrieval and machine learning based approach They are revolutionising the way look web search and automation service through the research and development standouts within the Natural Language Processing NLP Machine Learning field Each member the team are standouts within the from world class institution specialising research Machine Learning NLP with outstanding PhD the field Based right outside Old Street station Central London you will immersing yourself with expert the Machine Learning space The Role This unique chance work with team PhD candidate with experience within the Natural Language Processing domain building the next revolution within web search You will Develop unique entity extraction technique for web crawler and scraper Understand and analyse semantic relationship Work real time scraping and semantic extraction web data within ever changing environment expected demonstrate your finding national and international research venue Requirements PhD relating the and intuition for NLP representation and entity extraction something similar Alternatively have experience working within Solid programming skill use NLP Tools such GATE Job Owner rogers
#
#
#
#
# Job descr nr # 7
# Number vacancy Preference for Location London About Pangaea Data Limited Pangaea Data Limited provides machine learning based software product customer from the biopharmaceutical and healthcare industry for faster identification based phenotype clinical characteristic and symptom from electronic health EHRs and unstructured doctor note This critical for detecting patient risk disease finding gene linked phenotype drug biomarker recruiting patient for clinical real world evidence RWE study and matching the right patient with the right drug product demonstrated that able find the right 50x speed and higher accuracy alternative methodology such rule based natural language processing NLP keyword extraction and manual mean headquartered London and founded serial entrepreneur who have raised more than 130 million through their work and advised leading expert from industry Imperial College London and Stanford University Pangaea investor include based Deep Tech fund and renowned angel who founded several and headquartered Pangaea access million patient electronic health through partnership with hospital and other such provider from the Europe South America and Asia Pacific The Role Data Scientist Machine Learning and Natural Language Processing you are involved the research team need our researcher develop technology which can applied our product You also get chance work closely with engineer productise your research technology strong research skill and Machine Learning especially Natural Language Processing are essential What You Communicate with other researcher the engineer and the product team requirement Research and develop technology Text Mining and Natural Language Processing NLP Applying NLP technology for medical application Requirements With university qualification Bachelors Masters Doctorate who least two year university study Computer Science Medical Informatics Experience classroom work Machine learning Natural Language Processing Algorithmic Foundations Optimization Data Science Data Mining and Bioinformatics Experience general programming language Python Java Experience classroom work with popular framework TensorFlow PyTorch Nice Have Experience with and effort including having published paper being listed author NeuraIPS ICML ICLR ACL CVPR KDD etc Relevant work experience including internship full time industry experience researcher lab Perks and Benefits Flexible hour and remote working Flexible PTO Allocations learning and development Base with sale revenue and stock option Opportunity grow with into senior executive role Contact Details Please email your outlining your relevant experience Process The interview process will include three round The first round will software programming interview which aim evaluate your skill and algorithm design You will asked solve algorithm problem online within limited time independently The and third round will interview with our senior management which will focus your technical and personal skill during which you would expected answer question regarding your General Information Pangaea Data headquarters London with team San Francisco and Hong Kong For more information please visit www pangaeadata Pangaea Data equal opportunity employer All qualified applicant will for employment without regard sex sexual orientation gender identity expression religion national origin ancestry age disability marital status pregnancy protected veteran status protected genetic information political affiliation any other characteristic protected local law regulation ordinance
#
#
#
#
# Job descr nr # 8
# About Data Analytics within Global Research Data Analytics Morgan Corporate Investment machine learning technique with unique data asset optimize all the business decision make this role you will part our industry leading data analytics team and advance the state the art financial application ranging from generating business intelligence model and automated decision making The role will the firm Applied and Machine Learning organization and will involve working closely with Global Research About Global Research The firm Research team provides client with informed view and actionable idea economic indicator and asset class around the world Its top ranked research analyst strategist and economist are located developed and emerging economy CIB Research strives leader articulating unique and independent perspective the region where want business Clients the CIB Asset Management and other line business value the expertise Research helping them achieve their objective They with top tier ranking Institutional Investor Greenwich Associates Orion and many others Responsibilities The successful candidate will apply data analytics technique from both traditional statistic and machine learning third party publically available and JPMorgan proprietary datasets with the goal answering question relevant our Research analyst and the firm client Collaborate with formulate relevant financial and business question that can answered data analysis Research and analyze data set using variety statistical and machine learning techniquesCommunicate final result and approach and technique Work longer term project building tooling that can used scale certain type analysis across multiple datasets and business use case Collaborate with other Morgan machine learning team Required Technical Qualifications experience behaviour MSor PhD quantitative discipline Computer Science Mathematics Statistics Operations Research Data Science similar with experience ina highly quantitative position Hands onexperience analyzing data Experiencewith natural language processing NLP Strongability develop and debug Python similar professional programminglanguage Problemsolving skillsShouldbe able work both individually team order toachieve project goal Mustbe curious hardworking and and motivated problem Musthave the ability design evaluate intrinsic and extrinsic metric yourmodel performance which are aligned with business goal Mustbe able independently research and propose alternative with some guidanceas problem relevance Mustbe able undertake basic and advanced EDA may require some direction frommore senior team should aware limitation and implication methodologychoices Ensuresre use and sharing idea within team and locale Ableto work with non specialist partnership informationclearly and creates sense trust with stakeholder Nice Have Ideally some experience with machine learning APIs package example TensorFlow Theano PyTorch Keras Scikit Learn NumPy SciPy Pandas statsmodels Experiencewith big data technology such Hadoop Spark SparkML etc Showsinstitutional awareness and some understanding applied problem solving and guidance how most rapidly reach The hiring manager for this job opening about flexible working range from adhoc flexibility full time position more formal Flexible WorkArrangement 2020 JPMorgan Chase JPMorgan Chase anequal opportunity and affirmative action employer Disability Veteran Morgan global leader financial service providing strategic advice and product the world most government wealthy individual and institutional investor Our first class business first class way approach serving client drive everything strive build long term partnership help our client achieve their business objective that our people are our strength and the diverse talent they bring our global workforce are directly linked our success are equal opportunity employer and place high value diversity and inclusion not discriminate the basis any protected attribute including race nation ...
#
#
#
#
# Job descr nr # 9
# ABOUT THE TEAM Revolut Retail suite product that provide better and fairer way for people manage their money Our mission build the best suite financial service product for customer around the globe Virtually everyone the planet interacts with money are building game changing product that will make their life easier and keep them their financial world Each dedicated product team responsible for all aspect what they are building and legal business development and finance Teams operate independently like mini startup within Revolut with own tech and design resource This not only allows for fast paced development and pivot facilitates passionate close knit team that work closely together achieve their goal are looking build the best and most efficient customer experience the financial world ever seen leveraging automation and technology Natural Language Processing powered many Revolut product and you take the next level ABOUT THE ROLE You the CEO vertical within Revolut that solves world class problem with elegant and scaleable solution You make our chatbot more effective and able solve harder problem You apply sentiment analysis build engine and automate many Customer Experience process You explore and expand the product application NLP that deliver business value You read technical doc research regulation manage risk negotiate deal whatever take deliver amazing product You analyse prioritise optimise and repeat WHAT YOU NEED You have technical product management experience You have solid track achievement you have worked top start quickly assumed major responsibility award academic professional sport You can problem into smaller logical one and prioritise them with data You are fluent SQL and scripting language such Python and You are curious nature have great attention detail and have built product yourself You are entrepreneur who can make good business case people help you execute You hustle take ownership and get thing done little about When Revolut founded 2015 had vision build sustainable digital alternative traditional big bank Our mission now help our customer improve their financial health empower them have and promote across which operate Launching into 2020 with million Personal customer and over quarter million Business customer only reinforced our belief the vast need across the world for better financial service our customer base boomed the last year expanded our team match that growth started 2019 with several hundred employee closed out with 2000 What looking for Revolut being scaled people all around the world who share our vision looking for people who align with our value Never Settle Get Done because Think Deeper and Stronger Together You the kind person who want join forward thinking people all personally and professionally invested Revolut mission You thrive space where everyone learning from each other and learning fast believe empowering our Revoluters their work giving them autonomy and ownership what they want everyone Revolut own their story and their success working with mean you not just the machine THE BENEFITSCompetitive salaryBiannual equity bonusesAll the latest tech you and work from home once weekRoll with free Revolut Metal subscriptionPension plan Private health insuranceStart the day properly with fresh fruit and cerealsStay get juice and soft drink tapRest with day holiday per year
#
#
#
#
# Job descr nr # 10
# Country United Kingdom Job Family Product For over year GfK been reliable and trusted insight partner for the world and leading brand who make difference life and build this data science and innovative digital research solution provide answer for key business question market brand and medium With our headquarters Germany and presence around worldwide you benefit from our with 000 employee Harnessing the power our workforce the greatest asset have our people part GfK you can take your future into your own hand value talent skill and responsibility and support your development within our international team are proud our heritage and our future Currently are the latter stage transformational journey from traditional market trusted provider prescriptive data analytics powered innovative technology This only possible with extraordinary people and this why are looking for YOU help create our future For our employee well for our client pursue one goal Growth from Job Description are looking for you Senior Product Manager well versed Conversational Science NLP and excited driven search engine that provide highly accurate real time insight drawing thousand global data point advise and steer our global client who are world leading brand You will sit alongside world leading Data Scientists and Machine learning engineer you look get the most out our internal algorithm enhance our product offering This won walk the park but for the right individual who personally robust and willing challenge the status quo you will enjoy high growth curve from the exposure you will gain our newly formed Product org learning from the like Saied Head Product and Machine Learning Platforms GfK who will your manager this position Senior Product Manager you will have following key Building the GfK Search NLP service API capability based customer and product graph B2B environment line with real client Defining and building high scale customer data centric search platform enabling our client across the globe access meaningful information while having best navigation across GfK website and other client touchpoints with the most relevant search result practitioner Product Management you will own manage and prioritize quantitative focused backlog deliver meaningful optimization improvement across GfK search and NLP service APIs using agreed KPIs for relevance and performance based programmatic feature Involved the overall strategy defining and prioritizing business and working with the different business unit ensure their plan are Always putting client first you will work with other Product Managers Data Science architect and the development team deliver the roadmap using agile methodology prioritizing requirement answering development question and resolving issue Focusing our way working across the various team involved the development and ongoing management our GfK product portfolio you will proactively seeking improvement our process identify and develop new opportunity for GfK from perspective you will monitor and understand the potential new technology and business model Now that introduced you the position Senior Product Manager what skill qualification and experience should you have Familiarity with Aha Product management environment Deep understanding search indexing NLP Search stack elastic and Natural Language Processing NLP Articulating product strategy term client and business value and Past history product management based principal Judgement Impact Customer Insight Data centric Leading influencing Process technique Strategy innovation Understanding how customer journey work and how develop product optimize them Solid technical understanding understand the possibility technology and know when challenge and ask question you will need having You will have worked across the full lifecycle agile software development experience End End Product Ownership define design develop and deliver You will able demonstrate exposure and experience analytic platform deve ...
#
#
#
#
# Job descr nr # 11
# Site Name Hertfordshire Stevenage London Brentford USA California San USA Pennsylvania Upper Providence USA Pennsylvania Philadelphia Posted Date Jun 2020 GlaxoSmithKline have created world leading data environment enable large scale scientific experiment that exploit GSK unique access data Our focus bringing data analytics science together into solution for our scientist develop medicine for patient key enabler this effort the ability extract from unstructured text are seeking grow our team with brilliant and with natural language processing NLP expertise Our NLP team building system that read proprietary and public text datasets extract key information and make accessible throughout the organization This involves both leveraging state the art text processing model and developing new method derive actionable data for scientist are looking for NLP expert who are intrigued challenge information extraction including named entity relation extraction and entity linking This exciting role that will stretch your and curiosity offering the opportunity learn new skill and work within This hand position where you will empowered creative ambitious and bold solve novel problem and have the potential directly impact the life patient living with disease have impressive toolkits and world class data and are now looking for talented people join Machine Learning Engineer like you able Identify opportunity apply the latest advancement NLP and Machine Learning build test and validate model named entity relation extraction and entity linking Promote and use standard terminology and ontology UMLS Deploy your algorithm production service Automatically extract from the scientific literature with internal and external datasets graph Compare result from various methodology and best technique stake holder Connect with subject matter expert biology chemistry and medicine Why you Basic Qualifications are looking for professional with these required skill achieve our goal Masters PhD Natural Language Processing similar practical experience industrial research setting Refereed publication premiere NLP and bioinformatics venue one more area related information extraction such entity and relation extraction entity linking ontology alignment Experience using programming language such Python including fundamental software engineering principle and NLP machine learning design pattern Experience with least one Deep Learning framework such TensorFlow Keras PyTorch Preferred Qualifications you have the following characteristic would plus Excellent written and skill Experience applying NLP the domain include familiarity with terminology and ontology UMLS metathesaurus Ability work autonomously part team both teach and learn every day Why GSK Our value and expectation are the heart everything and form important part our culture These include Patient focus Transparency Respect Integrity along with Courage Development and Teamwork GSK focus our value and expectation and culture innovation performance and trust the successful candidate will demonstrate the following capability Agile and distributed decision making using evidence and applying judgement balance pace rigour and risk Managing individual and team performance Committed delivering high quality result challenge focusing what matter execution Implementing change initiative and leading change Sustaining energy and well being building resilience team Continuously looking for opportunity learn build skill and share learning both internally and externally Developing people and building talent pipeline Translating strategy into action narrative motivating others setting objective and delegation Building strong relationship managing trusted stakeholder relationship internally and externally Budgeting and and financial acumen GSK you require other assistance apply for job GSK the GSK Service Centre 877 694 7547 Toll Free Show phone number outside GSK Equal Opportunity Employer and the adhere Affirmative Action princi ...
#
#
#
#
# Job descr nr # 12
# About Eigen natural language processing machine learning B2B software focused transforming the operate unlocking the value their textual data Having our Series Eigen raised 60m date and backed Goldman Sachs Temasek Lakestar and Dawn Capital Whilst Eigen platform general and sector agnostic currently focused the Financial Services Legal and Insurance sector with client such Goldman Sachs BlackRock ING and Allen Overy Based London and New York Eigen over 130 people and rapidly scaling operation people and customer base Why join Eigen are building product the Natural Language Processing technology have exceptional Senior Management team with some the best mind across Sales Engineering Science and Product are diverse dynamic and supportive team with positive culture offer great office environment clear development path and many tangible benefit including Monthly Hackathons some some open 000 annual training budget Flexibility manage your work and Our Tech Stack but open others Python Django Numpy Pandas Machine Learning Natural Language Processing NLP What you need successful You motivated and capable engineer who passionate learning and growth well bringing the following key skill and experience Strong Software Engineer skill Machine Learning and Natural Language Processing NLP Algorithm design Experience building machine learning pipeline Eagerness learn grow and get stuck You form working relationship and partner based kindness understanding and mutual respect What you doing Because Researching googling and StackOverflowing find the latest software gadget love being and would Python Whiteboarding people architect shiny new feature Studying pull request make sure quality stay awesome Pair programming your way through difficult problem because two brain are better than one Building relationship with peer and teaching them thing you know Partnering closely with our frontend and solution engineer scientist our stack and the product team define and build new release Who you are You passionate about learning You care deeply about broadening your horizon and developing yourself and allow diverse perspective challenge your thinking You enjoy solving interesting problem you love challenged and find imaginative solution You like variety and think that the work the devil You have passion for working meaningful thing You biased towards acting You don like being micromanaged having babysitter you take pride identifying problem and taking responsibility for solving them About our team Our Research Development Science team Research Scientists Research Engineers Product Design Product SMEs Product Engineering and Solutions Engineering The Science team largely responsible for researching and developing new NLP solution which are then transformed into usable product the Engineering team Product Engineering focused building product offering while Solutions Engineering work with client deliver bespoke project and integration
#
#
#
#
# Job descr nr # 13
# Recruitment activity during the Covid outbreak for this role with interview taking place virtually Skype Zoom Hangouts etc NLP Data Scientist Data Engineer Machine LearningAre you experienced NLP Data Scientist looking for role that provides rewarding challenge the next step your career are currently looking for experienced talented Data Scientist assist with growth You will working within talented team and will responsible for developing Machine Learning Model Pipelines Learning Models and solution performance assessment for growing and Natural Language Processing NLP technology essential Our Data Scientists are integral member our team and involved influencing the creation sophisticated solution and ensuring their robustness This superb time join and part the growth You will Experienced working Data Scientist Data Python Pytorch and Natural Language Processing NLP technologyExperienced the deployment Machine Learning Models ProductionProficient AWSUnderstanding Transformer ModelsExperience working within the Machine Learning environment ideally part the role you will rewarded with the following attractive starting salary chance learn new technology techniquesA fun dynamic working environment Excellent career progressionSalary viewsAttractive holiday entitlementExcellent work life balanceRemote workingKey skill experience Python Pytorch TensorFlow NLP Natural Language Processing Data Scientist Data Engineer AWSJob Type PermanentSalary 000 000 per yearExperience Data Scientist Data Engineer year remotely Temporarily due COVID
#
#
#
#
# Job descr nr # 14
# Technical Solutions Consultant NLP Python Cloud Our client leading based start business are looking add experienced Technical Solutions Consultant NLP Python Cloud join expanding team London The Technical Solutions Consultant NLP Python Cloud will play critical role guiding customer demonstrating and deploying their bespoke platform top this The Technical Solutions Consultant NLP Python Cloud will demystify whilst working closely with data scientist and engineer fast growing the Technical Solutions Consultant NLP Python Cloud will used operating versatile environment scoping large scale project whilst supporting new business development Responsibilities for the Technical Solutions Consultant NLP Python Cloud Work directly with the sale team improve sale cycle Contribute partner strategy enablement and execution Engage the marketing event including speaking role Work under minimal supervision and prioritise effectively Oversee pilot both for existing customer and new sale opportunity Understand customer technology landscape business challenge and objective Customer and partner enablement including training Understand sale terminology process and best practice Requirements for the Technical Solutions Consultant NLP Python Cloud Technical experience operationalisation technology preferably Demonstrated experience customer facing sale support position Track delivering solution organisation Broad technical and experience deploying Solutions Natural Language Processing Cloud Architecture Concepts inc Microservices Kubernetes Kafka Coding Bash PowerShell Python Demonstrated critical thinking and have excellent written and verbal skill Tailoring solution and demonstration customer business Scoping documenting proposing and execution pilot Familiarity with modern project methodology Proven history overachieving performance and sale target Familiarity with mainstream CRM solution
#
#
#
#
# Job descr nr # 15
# Speech Research Engineer TTS ASR NLP Expert Specialist London Remote Worldwide Salary Negotiable based experience are partnered with very exciting client based London that looking expand high quality team with TTS Text Speech engineer You will working the speech technology alongside other technical expert Required Experience Tex speech TTS experience Automatic Speech ASR experience Natural Language Processing NLP Experience Deep Neural Networks Essential Python This role can either permanent role with highly flexible salary and rate This client have London based site working site Being they highly support remote working working site international worker are apply Sponsorship can provided for the right candidate you are interested finding out more about this exciting opportunity please submit your via the link provided and you shortly for discussion Cubiq Recruitment trusted supplier and interim recruitment service the technology and manufacturing sector are equal opportunity employer and value diversity not discriminate based race national origin gender sexual orientation age marital status veteran status disability status
#
#
#
#
# Job descr nr # 16
# Head Data Science London Cutting Edge NLP have been tasked with finding Head Data Science for true market disrupter transforming the way traditional market research carried out THE ROLE Head Data Science you will play crucial role leading team Data Scientists using advanced machine learning technique NLP Image Processing etc that utilises geo location technology social medium data and disparate data source provide insight real time The Head Data Science will report directly into the CEO and will also responsible for setting the business data strategy leading analytical project that will help increase business inefficiency doubling the size the current Data Science team and improve data driven decision across You will also called upon hand kind Head Data Science and lead your team example THE REQUIREMENTS Successful previous experience similar leadership role with responsibility for driving the growth and capability team Data ScientistsAbility demonstrate strong technical experience advanced analytics and machine learning model Strong demonstrable experience utilising Natural Language Processing NLP environment Any experience Image Processing will help you stand out from the crowd Hands experience with analytical language such Python etcExperience with RDBMS such Postrgres SQLExtensive skill data mining data modelling data driven organisation THE COMPANY really labour love having been started the founder who realised that get real time market research almost impossible They now offer platform that transforming the way their client Market Research and these include some the biggest brand the Internally they have exciting start vibe with culture openness and enthuses innovation Regular team social night free lunch Wednesdays and brainstorming around video game room are all regular happening THE OFFER Salary around the 120 000 130 000 markCompany options24 day pension schemeFlexible workingAnd more this sound like unique see yourself working apply now online send your today arrange exploratory chat Head Data Science London Natural Language Processing NLP Lawrence Harvey acting employment agency regard this position
#
#
#
#
# Job descr nr # 17
# Snapshot This rare opportunity for people who want problem and part the development transformative product Causaly backed startup working technology for Cause Effect and Epidemiology data extraction empowering researcher and decision maker quickly find causal evidence and generate insight from vast amount document Having already processed ten million academic publication and reading more than hundred thousand new paper every month our machine reading platform turn free flow text into causal graph and descriptive data structure and applies machine learning surface new are looking for engineer who will take the development our NLP pipeline the next level This specific opening implies work with rule based system and initial acquisition the information extraction module get ownership quickly The role looking for independent and individual who enjoy NLP problem get motivated seeing their work direct impact growing customer base and want apply their strategic mind ground breaking technology You working closely with the CTO and Product Owner joining close knit team and bright people You are resilient engineer experienced information extraction and thrive environment Responsibilities Work with rule based system Understand solution aimed the development our NLP pipeline using all aspect information extraction text processing and text understanding including design architecture and performance able inherit and develop further for particular information extraction module Work with Computational Linguist Product Manager iteratively engineering and implementing algorithm and linguistic rule improvement The role requires working with large volume data identify pattern for language modeling and able efficiently evaluate each such iteration before passing for Strong focus quality and performance based design Staying date with the state the art information extraction and general NLP method and technique Requirements Minimum Qualifications NLP Computational Linguistics equivalent experience MSc with year research experience Strong programming software engineering background enabling acquisition and scalable development Fluency fundamental NLP pipeline algorithm and tool preprocessing and normalization POS dependency parsing NER Experience NLP and Machine Learning library nltk spacy scikit learn Fluency with least one the modern distributed framework TensorFlow PyTorch Experience dealing with vast amount textual data optimization performance enhancement Ability drive technical project autonomously and work diverse environment Proficiency Python similar scripting language Preferred Qualifications Empirical research experience natural language processing and machine learning ideally the domain with focus information extraction Benefits Competitive Salary Share option all this together and you too shall own small part Health care insurance Individual training budget for professional development Plenty opportunity take more responsibility grow part multinational diverse and exceptional early team that build transformative product with the potential have real impact Regular team outing Annual team retreat secret destination Easily accessible office the heart Angel Islington right the station and tea because you can startup without caffeine Causaly application from all background diversity regardless gender religion belief ethnic national origin disability age citizenship marital domestic civil partnership status sexual orientation gender identity you have disability additional need that requires please not hesitate let know

# %%
nlp_df['mentions_research'] = nlp_df.job_descr.apply(lambda x : len(re.findall('research', x)))

# %%
nlp_df.head()
# Out:
#                                     company  \
# 2                 Digital insight-London N1
# 3                           Facebook-London
# 4           Evi Technologies Limited-London
# 5                         G-Research-London
# 6  Imperial College London-South Kensington
#
#                                            job_title  \
# 2                  Natural Language Processing (NLP)
# 3  Research Scientist, Natural Language Processin...
# 4  Applied Scientist - Information Retrieval and ...
# 5  Quantitative Researcher in Natural Language Pr...
# 6     Research Fellow in Natural Language Processing
#
#                                            job_descr  \
# 2  specialise and differentiate our ability extra...
# 3  Facebook mission give people the power and bri...
# 4  Machine Learning related disciplineStrong publ...
# 5  Imagine introducing the next generation techno...
# 6  Are you excellent data scientist with clear re...
#
#                job_search_term job_location  \
# 2  natural language processing       London
# 3  natural language processing       London
# 4  natural language processing       London
# 5  natural language processing       London
# 6  natural language processing       London
#
#                                              job_url  \
# 2  https://www.indeed.co.uk/rc/clk?jk=bfd3b0a1b6f...
# 3  https://www.indeed.co.uk/rc/clk?jk=2e174837e3a...
# 4  https://www.indeed.co.uk/rc/clk?jk=edc11c5d777...
# 5  https://www.indeed.co.uk/rc/clk?jk=744713011b6...
# 6  https://www.indeed.co.uk/rc/clk?jk=aef1fe9f820...
#
#    salary_from_page_source_as_stated  salary_from_page_source_conv_hourly  \
# 2                                NaN                                  NaN
# 3                                NaN                                  NaN
# 4                                NaN                                  NaN
# 5                                NaN                                  NaN
# 6                            53988.0                                  NaN
#
#    salary_from_page_source_time_period  Num_reviews  title_inc_nlp  \
# 2                                  NaN          NaN              1
# 3                                  NaN        579.0              1
# 4                                  NaN      63542.0              1
# 5                                  NaN          9.0              1
# 6                                  NaN        154.0              1
#
#    mentions_research
# 2                  1
# 3                  6
# 4                  5
# 5                  6
# 6                 16

# %%
nlp_df.mentions_research.value_counts()
# Out:
# 1     5
# 6     3
# 0     3
# 2     2
# 16    1
# 5     1
# 4     1
# 3     1
# Name: mentions_research, dtype: int64

# %% [markdown]
# It would seem that almost half of the mentions of 'research' come from one particular job post, which is...

# %%
print(nlp_df.loc[nlp_df.mentions_research==16].job_descr.iloc[0])
# Out:
# Are you excellent data scientist with clear research vision looking secure personal fellowship and establish your own research group The Data Science Institute DSI Imperial College wish nurture the next generation outstanding researcher and invite application for attractive and flexible fellowship scheme for those wishing develop independent research career You will carry out plan and lead high quality programme research Natural Language Processing and application undertake project management and supervise multi disciplinary team addition the Fellow will expected submit publication refereed journal and attract external research funding Duties and responsibility and original research Natural Language Processing and application obtain research grant from national and international funding body and obtain funding from industry where appropriate publish research paper peer reviewed journal attend and present research supervise postdoctoral researcher postgraduate student and undergraduate research project the DSI Essential requirement are looking for researcher any stage their career who have very good academic track including first upper degree and PhD science closely related discipline equivalent research industrial experience Experience the supervision research undergraduate postgraduate student postdoctoral staff Experience statistic data mining machine learning and natural language processing Experience directing the work small research team and motivate others produce high standard work Good modern programming language Java Python and management technology Docker Openstack Further information Contract Fixed Term for month Please apply via our website http www imperial job and search using vacancy reference number ENG01319 For query regarding the application Fay Miller For technical issue when applying online Documents Job Description ENG01319 pdf

# %% [markdown]
# .. unsurprisingly it's the job post from Imperial College London, which is specifically looking for a `Research Fellow`.

# %%
print(nlp_df.loc[nlp_df.mentions_research==16].job_title.iloc[0])
# Out:
# Research Fellow in Natural Language Processing

# %% [markdown]
# What if we look at the 3 jobs posts that mention research 6 times?
# Well, below, you can see that:
# *

# %%
for i in range(3):
    print(nlp_df.loc[nlp_df.mentions_research==6].job_descr.iloc[i])
    print('\n\n\n')
# Out:
# Facebook mission give people the power and bring the world closer together Through our family apps and service building different kind billion people around the world give them way share what matter most them and help bring people closer together Whether creating new product helping small business expand reach people Facebook are builder heart Our global team iterating solving problem and working together empower people around the world meaningful way Together can help people build just getting Billions people use our service their preferred language but many these language lack traditional NLP resource and our system need robust the informal tone slang and typo often found Our research span multiple area across NLP and machine learning including deep learning neural network machine translation natural language understanding and generation low resource NLP question answering dialogue and cross lingual and cross domain transfer learning are seeking world class natural language processing expert join our team developing next generation product and and publishing research and engineering scale applying language technology wide range medium understanding challenge Facebook Conduct research advance the state the art neural network and NLP Utilize that research develop and deploy scalable neural network model into production impact billion people using Facebook Collaborate with team member from other research and applied research team working variety deep learning and NLP problem Currently the process obtaining PhD degree postdoctoral assignment Natural Language Processing related field Experience with developing modern NLP system Proven track achieving result demonstrated grant fellowship patent well publication workshop such ACL EMNLP NAACL AAAI ICML NeurIPS similar Must obtain work authorization employment the time hire and maintain ongoing work authorization during employment
#
#
#
#
# Imagine introducing the next generation technology platform real time Research leading quantitative research and using the latest scientific technique produce world beating research and build advanced technology analyse the world data are developing the next generation infrastructure that can effortlessly scale and flex This capability allows adapt the demanding the business process and analyse large and varied data set Imagine beating the efficient market hypothesis with the full big data toolset Research leading quantitative research and using the latest scientific technique produce world beating research and build advanced technology analyse the world data use the latest scientific technique and advanced data analysis method the Our researcher are free explore idea finding pattern large noisy and real world data set the movement global financial market The Role You will join team NLP expert and quantitative researcher working very large applying the latest technique for entity sentiment analysis and topic extraction with the goal identifying feature real time text that can used the future behaviour financial market Who are looking for ideal candidate you will expert Natural Language Processing through academic industry experience both You will have experience applying machine learning and deep learning method range NLP related task such Named Entity Entity Linking Sentiment Analysis Graphs MultiLingual Text and Topic Extraction You will have experience working with existing NLP and deep learning framework such word spaCy CoreNLP NLTK PyTorch TensorFlow and Keras You will familiar with the many recent exciting advance NLP such pre trained language word attention and novel neural network architecture You will have interest applying real world financial data and implementing theoretical insight You will have working towards gaining Masters PhD degree NLP Computational Linguistics related quantitative subject such machine science mathematics statistic physic engineering Publications leading such ACL and EMNLP and such NeurIPS and ICML are highly desirable Previous financial experience not although interest finance and the motivation rapidly learn more prerequisite for working here Why should you plus annual discretionary bonus Informal and excellent work life balance Comprehensive healthcare and life assurance day holiday Pension Cycle work scheme Subsidised gym membership event Central London office close station and tube line
#
#
#
#
# Number vacancy Preference for Location London About Pangaea Data Limited Pangaea Data Limited provides machine learning based software product customer from the biopharmaceutical and healthcare industry for faster identification based phenotype clinical characteristic and symptom from electronic health EHRs and unstructured doctor note This critical for detecting patient risk disease finding gene linked phenotype drug biomarker recruiting patient for clinical real world evidence RWE study and matching the right patient with the right drug product demonstrated that able find the right 50x speed and higher accuracy alternative methodology such rule based natural language processing NLP keyword extraction and manual mean headquartered London and founded serial entrepreneur who have raised more than 130 million through their work and advised leading expert from industry Imperial College London and Stanford University Pangaea investor include based Deep Tech fund and renowned angel who founded several and headquartered Pangaea access million patient electronic health through partnership with hospital and other such provider from the Europe South America and Asia Pacific The Role Data Scientist Machine Learning and Natural Language Processing you are involved the research team need our researcher develop technology which can applied our product You also get chance work closely with engineer productise your research technology strong research skill and Machine Learning especially Natural Language Processing are essential What You Communicate with other researcher the engineer and the product team requirement Research and develop technology Text Mining and Natural Language Processing NLP Applying NLP technology for medical application Requirements With university qualification Bachelors Masters Doctorate who least two year university study Computer Science Medical Informatics Experience classroom work Machine learning Natural Language Processing Algorithmic Foundations Optimization Data Science Data Mining and Bioinformatics Experience general programming language Python Java Experience classroom work with popular framework TensorFlow PyTorch Nice Have Experience with and effort including having published paper being listed author NeuraIPS ICML ICLR ACL CVPR KDD etc Relevant work experience including internship full time industry experience researcher lab Perks and Benefits Flexible hour and remote working Flexible PTO Allocations learning and development Base with sale revenue and stock option Opportunity grow with into senior executive role Contact Details Please email your outlining your relevant experience Process The interview process will include three round The first round will software programming interview which aim evaluate your skill and algorithm design You will asked solve algorithm problem online within limited time independently The and third round will interview with our senior management which will focus your technical and personal skill during which you would expected answer question regarding your General Information Pangaea Data headquarters London with team San Francisco and Hong Kong For more information please visit www pangaeadata Pangaea Data equal opportunity employer All qualified applicant will for employment without regard sex sexual orientation gender identity expression religion national origin ancestry age disability marital status pregnancy protected veteran status protected genetic information political affiliation any other characteristic protected local law regulation ordinance

# %%
nlp_skill_df = df.loc[df.title_inc_nlp == 0]
nlp_skill_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 106 entries, 0 to 122
# Data columns (total 11 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   company                              106 non-null    object
#  1   job_title                            106 non-null    object
#  2   job_descr                            106 non-null    object
#  3   job_search_term                      106 non-null    object
#  4   job_location                         106 non-null    object
#  5   job_url                              106 non-null    object
#  6   salary_from_page_source_as_stated    22 non-null     float64
#  7   salary_from_page_source_conv_hourly  0 non-null      float64
#  8   salary_from_page_source_time_period  0 non-null      float64
#  9   Num_reviews                          46 non-null     float64
#  10  title_inc_nlp                        106 non-null    int64
# dtypes: float64(4), int64(1), object(6)
# memory usage: 9.9+ KB

# %%
nlp_skill_df['mentions_research'] = nlp_skill_df.job_descr.apply(lambda x : len(re.findall('research', x)))
nlp_skill_df.mentions_research.value_counts()
# Out:
# 0     58
# 1     20
# 3      5
# 2      5
# 9      4
# 6      3
# 5      3
# 12     2
# 10     2
# 16     1
# 8      1
# 7      1
# 4      1
# Name: mentions_research, dtype: int64

# %% [markdown]
# 'Research' is still quite prominent even within this group, although more than half of the descriptions in this subset do not mention it at all and one post mentioning it 16 times (which happens to be, again a )

# %%
nlp_skill_df.loc[nlp_skill_df.mentions_research==16].job_descr.iloc[0]
# Out:
# 'Job Requisition 20WD42011 Position Overview The User Interface Research Group Autodesk Research seeking exceptionally talented research scientist work research the intersection Human Computer Interaction and Artificial Intelligence include research topic such intelligent user interface adaptive and personalized user interface novel approach into software application technique for providing insight user based usage data end user machine learning other novel technique for interacting with system human robot interaction and natural language processing Successful candidate will have demonstrated track broadly research result and publication venue ACM CHI UIST IUI NeurIPS AAAI similar Responsibilities The overall mission the User Interface Research Group apply Human Computer Interaction expertise develop fundamental understanding how human perceive learn and interact with technology and based these understanding develop novel interface and visualizationsto solve current problem explore future opportunity and influence strategy particular area interest for our group how the digital trail that human leave they interact with technology and the environment can used improve their future experience Your responsibility will Conceive plan develop and implement scientific research project advance scientific business relevant area Publish paper peer reviewed scientific Supervise research intern typically PhD student from top research university Present research finding and participate with external research institute and university Communicate and promote the use research finding throughout Autodesk Consult with product team the implementation research finding into product Generate intellectual property such patent and trade secret from research finding Manage project they move from research prototype shipping product service Minimum Qualifications Computer Science Engineering Mathematics other relevant discipline ideally the topic Human Computer Interaction closely related area Demonstrated experience HCI research fundamental including experience designing and evaluating novel interface and technology Strong history publication HCI related field Solid working latest and technology and research including experience implementing modern algorithm DNNs and familiarity with various standard statistical and technique classification regression dimension reduction regularization clustering and various multivariate method Excellent written and skill Ability quickly learn new technology and adapt new situation Ability quantitative and qualitative study design and system Ability with people from many different discipline design development etc About Autodesk Research Autodesk Research team expert scientist exploring and creating technology help improve design and role society through high level customer with leading research university worldwide and publication world renowned scientific venue Autodesk building diverse workplace and inclusive culture give more people the chance imagine design and make better world Autodesk proud equal opportunity employer all qualified applicant for employment without regard religion age sex sexual orientation gender gender identity national origin disability veteran status any other legally protected characteristic for employment all qualified applicant regardless criminal with applicable law Are you with Autodesk Please search for open job and apply internally not this external site you have any question require Autodesk Careers '

# %%
fn.plot_freqdist_from_series(nlp_skill_df.job_descr, tokenizer, nlp_stop_word_lst, ngram_number=1);

# %%
fn.plot_freqdist_from_series(nlp_skill_df.job_descr, tokenizer, nlp_stop_word_lst, ngram_number=2);

# %%
fn.plot_freqdist_from_series(nlp_skill_df.job_descr, tokenizer, nlp_stop_word_lst, ngram_number=3);

# %% [markdown]
# <a id=conc ><a/>
#
# ## 3. Summary of findings
#
# [LINK to table of contents](#contents)
